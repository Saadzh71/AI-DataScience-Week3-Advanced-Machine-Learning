# %% [markdown]
# # Exam on Convolutional Neural Networks (CNN)
#
# Welcome to the Convolutional Neural Networks (CNN) practical exam. In this exam, you will work on an image classification task to predict weather the parkinglot is occupied or empty. You are provided with a dataset of parkinglot images, and your task is to build, train, and evaluate a CNN model.
#
# ---
#
# ## Dataset Overview
# ### **Dataset:**
# * Just run the command under the `Load Data` section to get the data downloaded and unzipped or you can access it [here](www.kaggle.com/datasets/khaledzsa/parkinglot-occupation)
# ### **Dataset Name:** ParkingLot Occupation
#
# ### **Description:**
# The dataset contains images of labeld parkinglot images for classification purposes. Each image belongs to one of the 2 classes, representing the label.
#
# ### **Labels:**
# * `empty`
# * `occupied`

# %% [markdown]
# ## Load Data
# Run the following command to get the data and unzip it, alternatively you can access the data [here](www.kaggle.com/datasets/khaledzsa/parkinglot-occupation).

# %%
# !kaggle datasets download -d khaledzsa/parkinglot-occupation
# !unzip parkinglot-occupation.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/khaledzsa/parkinglot-occupation
# License(s): unknown
# parkinglot-occupation.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  parkinglot-occupation.zip
# replace ParkingLot_Occupation/test/empty/roi_004a880991fb418298519ca2616f3147_empty.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ParkingLot_Occupation/test/empty/roi_004a880991fb418298519ca2616f3147_empty.jpg
# replace ParkingLot_Occupation/test/empty/roi_01a29d413e3642d39e11414dc6e95501_empty.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ParkingLot_Occupation/test/empty/roi_01a29d413e3642d39e11414dc6e95501_empty.jpg
# replace ParkingLot_Occupation/test/empty/roi_023ee6f9ea20407da126475ef5bfe567_empty.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: ParkingLot_Occupation/test/empty/roi_023ee6f9ea20407da126475ef5bfe567_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_03fffe90162c4e06be43e47f34d9e83a_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_04c6ff9e977d4f59bbf963bfb97f6872_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_0571fcbaa9b94ddfaf5c65edad33e59e_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_064a5abf3c7d47f9942f77da2a2af7e7_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_066690ec6e534d9fbe6be7f9acffb48d_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_07f6578b514e4b54a135f81c04571fc4_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_0840628434524f87baa62778362a7e89_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_0bb541983ba048d5802d6c7e107791bd_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_0d7863044f3b4e6c828f18e50c5ed0a3_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_0ddb9ff62d114ea1ba02efcd74368497_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_0ee6e0e0daf2487fa3ed3000f4d23be4_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_0f0fd73fa1a241db8238fe56440aca74_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_0fb0fc68033745a790ef4f7f3162f95f_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_12836ba136654d5481f002d05ef7e87a_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_1521dd5e1c3b405f9dbd4b634f9d9571_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_15c7e2f08b7a4502a386c5b292fd3cb1_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_16c8b0b75f67453e8a508206f2a1dbda_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_16cd3626b0604d3d89c795b0d86e9bac_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_17c0a8cbe2594652bff03763c0305203_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_18002d58f2434dd2b70424140d1a4de6_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_1969688e5d2e4021ad50dd0840bb05dc_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_1a2d9a08db4f4633b0efc1e816b4f736_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_1a790bd8c4eb41cea97df913709f5b73_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_1c159ef694684f95b72d84804ba45f32_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_1c1f9a5f7d354453a65dc3f9a68769d6_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_1c99235ccef5414ab83aa60346f7b7b0_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_1d731479454d43dbb99eb9ba288c9a55_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_1f32a19b2f4b40d090c90281e073538d_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_22a3d5cb6f1f4156b54214432e5f9f0e_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_233147d9eb6c45619cd0474919036bcd_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi_2a45dde3b7e947cab6f7f029c0730b83_empty.jpg
#   inflating: ParkingLot_Occupation/test/empty/roi
occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_f91c5bf7c5ba49ca91b7dc7cbfdfd4d4_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_f95b53710c0646a3ad37fc1bc459a72b_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_f9606124483a4335ae7e273793bb1026_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_f9e22ea7744340b49a751030fa172000_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_fafdc0430ec74652a4de3a189c0caef5_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_fafea706182d4cbc96080d9dcce088c6_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_fb3602cdcbb442c6aeb043c5b5d6eda7_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_fb7b69ea76104e4383d065b2f73d1e11_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_fb87e47984324725ba731a37fb4e862b_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_fbff5fb7215746e2afcfa5120afe0a4f_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_fc601e13b1394ac7ad6a3e7df5483e97_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_fc96cddfd79e4ac3a14c328e65e57b22_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_fca178acbce7403cae229b5e1109fdd2_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_fd0fd206204a43ea94f27117cbb0e1ed_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_fe9bf836aa704f678625e0039b57d068_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_fed6819dfb2a4585957bf8dd12b2206b_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_ff41a85b821749d8aebe8eb58e161700_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_ffa479398c4e41ceaf7d330b6cc6cef8_occupied.jpg
#   inflating: ParkingLot_Occupation/train/occupied/roi_fff91c7d78e2472193ae94906cf048fb_occupied.jpg

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
import keras
from tensorflow.keras.layers import Dense
from keras import layers
from tensorflow import data as tf_data
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## Data Preprocessing
# In this section, preprocess the dataset by:
# - Loading the images from the file paths.
# - Resizing the images to a consistent size.
# - Normalizing pixel values.
#
# Add more if needed!

# %%
image_size = (128, 128)
batch_size = 64

train_ds, val_ds = keras.utils.image_dataset_from_directory(
    "/content/ParkingLot_Occupation/train",
    validation_split=0.2,
    subset="both",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 1382 files belonging to 2 classes.
# Using 1106 files for training.
# Using 276 files for validation.

# %% [markdown]
# ## Data Splitting
# In this section, we will split our dataset into three parts:
#
# * `train` Folder: Training set (85%).
# * `train` Folder: Validation set (15%).
# * `test` Folder: Test set (100%).

# %%
image_size = (128, 128)
batch_size = 64

test_ds = keras.utils.image_dataset_from_directory(
    "/content/ParkingLot_Occupation/test",
    seed=1337,
    image_size=image_size ,
    batch_size=batch_size,
)
# Out:
# Found 344 files belonging to 2 classes.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(images[i]).astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
]


def data_augmentation(images):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(augmented_images[0]).astype("uint8"))
        plt.axis("off")

# %%
# Apply `data_augmentation` to the training images.
train_ds = train_ds.map(
    lambda img, label: (data_augmentation(img), label),
    num_parallel_calls=tf_data.AUTOTUNE,
)
# Prefetching samples in GPU memory helps maximize GPU utilization.
train_ds = train_ds.prefetch(tf_data.AUTOTUNE)
val_ds = val_ds.prefetch(tf_data.AUTOTUNE)

# %% [markdown]
# ## Building the CNN Model
# In this section, define the architecture of the CNN model. The architecture may consist of:
# - Convolutional layers with max-pooling
# - Dropout layers
# - Flatten layer
# - Dense layers
# - Output layer
#
# Add and remove any of these as needed!

# %%
model = Sequential([
  #Input layer
  layers.Input(shape=(128, 128, 3)),

  # Normalization and rescale
  layers.Rescaling(1./255.),

  # Conv block
  layers.Conv2D(32, kernel_size=(4, 4), activation='relu'),
  layers.MaxPool2D(2,2),
  layers.Flatten(),

  #Hidden Layers
  layers.Dense(16, activation="relu"),
  layers.Dense(8, activation="relu"),

  # Dropout layer
  tf.keras.layers.Dropout(0.2),

  # Output Layer
  layers.Dense(1, activation="sigmoid")
  ])

# %%
# Compile

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_2 (Rescaling)              │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 125, 125, 32)        │           1,568 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 62, 62, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 123008)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 16)                  │       1,968,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,969,857 (7.51 MB)
#  Trainable params: 1,969,857 (7.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training the Model
# Train the CNN model using the training data and validate it on the validation set.

# %%
history = model.fit(train_ds, batch_size=batch_size, epochs=10, validation_data=val_ds)
# Out:
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 211ms/step - accuracy: 0.5782 - loss: 0.8768 - val_accuracy: 0.8043 - val_loss: 0.4708
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.7690 - loss: 0.4836 - val_accuracy: 0.8841 - val_loss: 0.3748
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - accuracy: 0.7884 - loss: 0.4027 - val_accuracy: 0.9348 - val_loss: 0.2905
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.8493 - loss: 0.3528 - val_accuracy: 0.9275 - val_loss: 0.2560
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - accuracy: 0.8645 - loss: 0.3048 - val_accuracy: 0.9420 - val_loss: 0.2453
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.8703 - loss: 0.3292 - val_accuracy: 0.9094 - val_loss: 0.2362
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.8629 - loss: 0.3350 - val_accuracy: 0.9457 - val_loss: 0.2778
# Epoch 8/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.8877 - loss: 0.2927 - val_accuracy: 0.8841 - val_loss: 0.2488
# Epoch 9/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - accuracy: 0.8780 - loss: 0.2899 - val_accuracy: 0.9601 - val_loss: 0.1793
# Epoch 10/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - accuracy: 0.9192 - loss: 0.2392 - val_accuracy: 0.9275 - val_loss: 0.1841

# %% [markdown]
# ## Evaluate the Model
# Evaluate the performance of the model on the test set.

# %%
model.evaluate(val_ds)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9166 - loss: 0.2018
# [0.18413595855236053, 0.9275362491607666]

# %% [markdown]
# ## Make Predictions
# Use the trained model to make predictions on new or unseen parkinglot images.

# %%
ypred = model.predict(test_ds)
ypred
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# array([[0.3668862 ],
#        [0.9998135 ],
#        [0.09893162],
#        [0.9842609 ],
#        [1.        ],
#        [0.07472079],
#        [0.33055705],
#        [0.1099774 ],
#        [0.99999976],
#        [0.9995414 ],
#        [0.9999993 ],
#        [0.9999999 ],
#        [0.99997294],
#        [0.99987435],
#        [0.11430729],
#        [0.08591673],
#        [0.04130065],
#        [0.04373709],
#        [0.9992648 ],
#        [0.05257946],
#        [0.21624132],
#        [0.99999595],
#        [0.10418404],
#        [0.03448649],
#        [0.04365857],
#        [0.9999236 ],
#        [0.9882752 ],
#        [0.3004954 ],
#        [0.08987101],
#        [0.99999964],
#        [0.9999982 ],
#        [0.10506005],
#        [0.07020586],
#        [0.05416084],
#        [0.03356137],
#        [0.05435452],
#        [0.07967943],
#        [0.08952955],
#        [0.07823532],
#        [0.12431348],
#        [0.9998068 ],
#        [0.99996746],
#        [0.14516938],
#        [0.9867431 ],
#        [0.05391635],
#        [0.15078436],
#        [0.7085064 ],
#        [0.06102495],
#        [0.04081528],
#        [0.0787746 ],
#        [0.06109976],
#        [0.15977785],
#        [0.05137195],
#        [0.9959245 ],
#        [1.        ],
#        [0.9998097 ],
#        [0.38728213],
#        [0.06033043],
#        [0.94986767],
#        [0.06133193],
#        [0.11582794],
#        [0.99938333],
#        [0.9999982 ],
#        [0.10707889],
#        [0.9999913 ],
#        [0.06525346],
#        [0.7477988 ],
#        [0.35981083],
#        [0.6598588 ],
#        [0.5298811 ],
#        [0.99948406],
#        [0.19279413],
#        [0.9799697 ],
#        [0.9464478 ],
#        [0.98166794],
#        [0.03632124],
#        [0.54934466],
#        [0.75023264],
#        [0.99608743],
#        [0.999995  ],
#        [0.9999999 ],
#        [0.0694675 ],
#        [0.14993718],
#        [0.7575052 ],
#        [0.9992237 ],
#        [0.94952303],
#        [0.9999999 ],
#        [0.97829163],
#        [0.9999554 ],
#        [0.06858722],
#        [0.08011573],
#        [0.5888931 ],
#        [0.7024431 ],
#        [0.9962289 ],
#        [0.34290686],
#        [0.02644661],
#        [0.02569566],
#        [0.07980519],
#        [0.9999273 ],
#        [0.07210153],
#        [0.08440938],
#        [0.04033456],
#        [0.07836336],
#        [1.        ],
#        [0.04551238],
#        [0.20148611],
#        [0.98707646],
#        [0.22871003],
#        [0.5223612 ],
#        [0.05086949],
#        [0.09759363],
#        [0.1384366 ],
#        [0.999992  ],
#        [0.999624  ],
#        [0.9999862 ],
#        [0.34141913],
#        [0.99990904],
#        [0.99998736],
#        [0.7531883 ],
#        [0.35419828],
#        [0.13074413],
#        [1.        ],
#        [0.9999993 ],
#        [0.14226456],
#        [0.04987667],
#        [0.11893768],
#        [0.99914896],
#        [0.04345458],
#        [0.07087378],
#        [0.07827154],
#        [0.98473674],
#        [0.6531189 ],
#        [0.9995092 ],
#        [0.41834337],
#        [0.06200421],
#        [0.9999937 ],
#        [0.3307925 ],
#        [0.99992836],
#        [0.08034978],
#        [0.07910199],
#        [0.9837659 ],
#        [0.057515  ],
#        [0.9999168 ],
#        [0.0511236 ],
#        [0.04718079],
#        [1.        ],
#        [0.05623094],
#        [0.09812263],
#        [0.9999244 ],
#        [0.99914396],
#        [0.07622287],
#        [0.1129552 ],
#        [0.99999726],
#        [0.9999883 ],
#        [0.087358  ],
#        [0.0513658 ],
#        [0.99940646],
#        [0.9999882 ],
#        [0.98157746],
#        [0.07322867],
#        [0.13832167],
#        [0.9999994 ],
#        [0.99425006],
#        [0.26281202],
#        [0.99997795],
#        [1.        ],
#        [0.20884606],
#        [0.7034386 ],
#        [0.9999993 ],
#        [0.99993515],
#        [0.14033015],
#        [0.03807919],
#        [0.04850637],
#        [0.12297584],
#        [0.75969356],
#        [0.18128447],
#        [0.04787978],
#        [0.05598814],
#        [0.05433244],
#        [0.03602842],
#        [0.99999964],
#        [0.07203618],
#        [0.08814918],
#        [0.3205769 ],
#        [0.09010614],
#        [0.04256184],
#        [0.9999063 ],
#        [1.        ],
#        [0.06249294],
#        [0.03204317],
#        [0.6604783 ],
#        [0.98688847],
#        [0.999286  ],
#        [0.04436755],
#        [0.41287312],
#        [0.9998869 ],
#        [0.32217234],
#        [0.9149242 ],
#        [0.05607581],
#        [0.17413646],
#        [0.9903154 ],
#        [0.99969923],
#        [0.03879176],
#        [0.26378858],
#        [0.99998415],
#        [0.6400688 ],
#        [0.2541374 ],
#        [0.25510147],
#        [0.09946959],
#        [0.62081873],
#        [0.9990736 ],
#        [0.94387555],
#        [0.92851174],
#        [0.04428652],
#        [0.06246581],
#        [0.10269551],
#        [0.25421095],
#        [0.77070403],
#        [0.30188942],
#        [0.98963565],
#        [0.8200181 ],
#        [1.        ],
#        [0.9328671 ],
#        [0.99993527],
#        [0.0934419 ],
#        [0.99999917],
#        [0.99983263],
#        [0.91780597],
#        [0.05284526],
#        [0.08351506],
#        [0.03856791],
#        [0.19314219],
#        [0.15375286],
#        [0.09761425],
#        [0.31171134],
#        [0.03311227],
#        [0.07189789],
#        [0.10200649],
#        [0.05365732],
#        [0.51958877],
#        [0.06299734],
#        [0.41976076],
#        [0.32689506],
#        [0.03654089],
#        [0.02746421],
#        [0.06639895],
#        [0.9996414 ],
#        [0.9751534 ],
#        [0.06880782],
#        [0.9999883 ],
#        [0.19203144],
#        [0.94883066],
#        [0.99970466],
#        [0.14457786],
#        [0.98958826],
#        [0.55465776],
#        [0.9996076 ],
#        [0.06522952],
#        [0.13533157],
#        [0.99961287],
#        [0.9983302 ],
#        [0.7598033 ],
#        [0.04552628],
#        [0.07681821],
#        [0.03769618],
#        [0.0772918 ],
#        [0.07034891],
#        [0.99999976],
#        [0.07179816],
#        [0.06476621],
#        [1.        ],
#        [0.14700484],
#        [0.04717531],
#        [0.08959155],
#        [0.05038575],
#        [0.05371512],
#        [0.11076034],
#        [0.9995602 ],
#        [0.9999294 ],
#        [0.7784046 ],
#        [0.07140103],
#        [0.09834211],
#        [0.9741638 ],
#        [0.14992537],
#        [0.1178085 ],
#        [0.9997378 ],
#        [0.9989343 ],
#        [0.12705623],
#        [0.9997799 ],
#        [0.10765786],
#        [0.07852247],
#        [0.9999999 ],
#        [1.        ],
#        [0.99120784],
#        [0.55308753],
#        [0.09815966],
#        [0.9999175 ],
#        [0.04347151],
#        [0.03996733],
#        [0.9999862 ],
#        [0.1928391 ],
#        [0.09059233],
#        [0.99223137],
#        [0.03123581],
#        [0.04399727],
#        [0.99081624],
#        [0.13049357],
#        [0.07604473],
#        [0.9999995 ],
#        [0.08618163],
#        [0.3772293 ],
#        [0.12400702],
#        [0.05208885],
#        [0.10343922],
#        [0.06226771],
#        [0.07101251],
#        [0.99999964],
#        [0.7332737 ],
#        [0.06950032],
#        [0.06432898],
#        [0.99999595],
#        [0.18143927],
#        [0.04456894],
#        [0.5712198 ],
#        [0.39548275],
#        [0.9373568 ],
#        [0.03799427],
#        [0.9901106 ],
#        [0.07630278],
#        [0.96966815],
#        [0.10124524],
#        [0.3201132 ],
#        [0.9999776 ],
#        [0.03027169],
#        [0.9999565 ],
#        [0.9999883 ],
#        [0.02754759],
#        [0.5427089 ],
#        [0.21672916],
#        [0.03484204],
#        [0.66072166],
#        [0.10746571],
#        [0.05920252],
#        [0.05129533]], dtype=float32)

# %% [markdown]
# if you need new, we prepared some data for you [here](www.kaggle.com/datasets/khaledzsa/parkinglot-occupation), or you can simply run the following command to get the data and unzip it.
#
# <small>Note: please note that the file contain MetaData to tell you what each image contains <b>THIS IS JUST FOR YOU TO MAKE SURE</b></smmall>

# %% [markdown]
# If you ran the command above, you should have a file called ParkingLot_Occupation in your current directory. which contains the testing dataset.
# If you ran the command above <span style='color:red;'>DON'T RUN THIS CELL</span>

# %%
#!kaggle datasets download -d khaledzsa/parkinglot-occupation
#!unzip parkinglot-occupation.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/khaledzsa/parkinglot-occupation
# License(s): unknown
# parkinglot-occupation.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  parkinglot-occupation.zip
# replace ParkingLot_Occupation/test/empty/roi_004a880991fb418298519ca2616f3147_empty.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# ## Model Performance Visualization
# Visualize performance metrics such as accuracy and loss over the epochs.

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.plot(history.history['loss'], label = 'Loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %% [markdown]
# ## Save the Model
# Save the trained CNN model for submission.

# %%
model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Project Questions:
#
# 1. **Data Preprocessing**: Explain why you chose your specific data preprocessing techniques (e.g., resizing images, normalization, data augmentation). How do these preprocessing steps improve the performance of your CNN model?
# 2. **Model Architecture**: Describe the architecture of your CNN model (e.g., number of convolutional layers, kernel sizes, pooling layers). Why did you choose this structure, and how do you expect each layer to contribute to feature extraction?
# 3. **Activation Functions**: Justify your choice of activation functions. How do they influence the training and output of your CNN?
# 4. **Training Process**: Discuss your choice of batch size, number of epochs, and optimizer. How did these decisions impact the training process and the convergence of the model?
# 5. **Loss Function and Metrics**: Explain why you chose the specific loss function and evaluation metrics for this classification task. How do they align with the goal of correctly classifying parkinglot?
# 6. **Regularization Techniques**: If you used regularization methods like dropout or batch normalization, explain why you implemented them and how they helped prevent overfitting in your model.
# 7. **Model Evaluation**: Justify the method you used to evaluate your model's performance on the test set. Why did you select these evaluation techniques, and what insights did they provide about your model's accuracy and generalization ability?
# 8. **Model Visualization**: Explain the significance of the performance visualizations (e.g., accuracy and loss curves). What do they tell you about your model's training process and its ability to generalize?
# 9. **Overfitting and Underfitting**: Analyze whether the model encountered any overfitting or underfitting during training. What strategies could you implement to mitigate these issues?

# %% [markdown]
# ### Answer Here:
#  - A1/ Resizing: makes it easier and lighter for the performance and faster normalization: makes it between 1 and 255 to because colors are between 1,255 so then it is easier for the machine and ram.  Data augmentation: generate more images from existing images to save time and effort to imporve the accuracy by rotating and rescaling images.
#
#  - A2/ Input layer: for the input. Normalization and rescaling to make it easier for the machine. Conv layer: to apply a small filter to process data of the images as a small block of pixels. Hidden layer: to make each neuron focus on one shape. Dropout: to not make some neurons overfit and get used to some shapes while others lack in accuacy. Output layer: used sigmoid because output must be either of 2 states either 0 or 1.
#
#  - A3/ Used mostly relu to make values between (0, +infinity). and sigmoid for binary crossentropy.
#
#  - A4/ batch size: tested with 64 and found out its good and not so big. number of epochs: found out that 10 is a good starting point and could increase it slightly. optimizer: i choose adam because it is the default of the library and it has proven to be good :).
#
#  - A5/ I used binary_crossentropy because it is a binary classification.
#
#  - A6/ Used Dropout to not overfit some neurons and leave others not learning anything.
#
#  - A7/ I evaluated it and it is aligning with my outcomes and doesnt seem like there is much overfitting or underfitting.
#
#  - A8/ used Accuracy, Val_Accuracy and Loss to plot my results.
#
#  - A9/ I think my model has a good fit of the data. I didnt undertrain it or overtrained it.
